# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
# read the csv file

df = pd.read_csv('/Users/sdfd/Downloads/data.csv')
df.head(10)
# Out:
#    Unnamed: 0 Unnamed: 1 Life expectancy at birth (years)  \
# 0  WHO region       Year                       Both sexes
# 1      Global       2019                             73.3
# 2      Global       2015                             72.3
# 3      Global       2010                             70.5
# 4      Global       2000                             66.8
# 5      Africa       2019                             64.5
# 6      Africa       2015                             62.6
# 7      Africa       2010                             59.5
# 8      Africa       2000                             52.7
# 9    Americas       2019                             77.2
#
#   Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# 0                               Male                             Female
# 1                               70.8                               75.9
# 2                               69.8                               74.9
# 3                               68.0                               73.2
# 4                               64.4                               69.3
# 5                               62.4                               66.6
# 6                               60.5                               64.7
# 7                               57.7                               61.3
# 8                               51.1                               54.3
# 9                               74.5                               79.8
#
#   Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# 0                        Both sexes                                Male
# 1                              21.1                                19.5
# 2                              20.8                                19.1
# 3                              20.1                                18.4
# 4                              18.8                                17.2
# 5                              17.9                                16.7
# 6                              17.4                                16.2
# 7                              16.8                                15.5
# 8                              15.5                                14.3
# 9                              22.7                                21.2
#
#   Life expectancy at age 60 (years).2  \
# 0                              Female
# 1                                22.7
# 2                                22.3
# 3                                21.7
# 4                                20.4
# 5                                19.0
# 6                                18.5
# 7                                18.0
# 8                                16.8
# 9                                24.0
#
#   Healthy life expectancy (HALE) at birth (years)  \
# 0                                      Both sexes
# 1                                            63.7
# 2                                            62.9
# 3                                            61.5
# 4                                            58.3
# 5                                            56.0
# 6                                            54.4
# 7                                            51.8
# 8                                            45.8
# 9                                            66.2
#
#   Healthy life expectancy (HALE) at birth (years).1  \
# 0                                              Male
# 1                                              62.5
# 2                                              61.7
# 3                                              60.2
# 4                                              57.1
# 5                                              55.0
# 6                                              53.4
# 7                                              51.0
# 8                                              45.0
# 9                                              64.8
#
#   Healthy life expectancy (HALE) at birth (years).2  \
# 0                                            Female
# 1                                              64.9
# 2                                              64.2
# 3                                              62.9
# 4                                              59.6
# 5                                              57.1
# 6                                              55.5
# 7                                              52.6
# 8                                              46.6
# 9                                              67.5
#
#   Healthy life expectancy (HALE) at age 60 (years)  \
# 0                                       Both sexes
# 1                                             15.8
# 2                                             15.5
# 3                                             15.1
# 4                                             14.1
# 5                                             13.3
# 6                                             12.9
# 7                                             12.5
# 8                                             11.5
# 9                                             16.6
#
#   Healthy life expectancy (HALE) at age 60 (years).1  \
# 0                                               Male
# 1                                               14.8
# 2                                               14.6
# 3                                               14.1
# 4                                               13.1
# 5                                               12.6
# 6                                               12.2
# 7                                               11.7
# 8                                               10.7
# 9                                               15.7
#
#   Healthy life expectancy (HALE) at age 60 (years).2
# 0                                             Female
# 1                                               16.6
# 2                                               16.4
# 3                                               16.1
# 4                                               15.1
# 5                                               13.9
# 6                                               13.6
# 7                                               13.2
# 8                                               12.3
# 9                                               17.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 14 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Unnamed: 0                                          29 non-null     object
#  1   Unnamed: 1                                          29 non-null     object
#  2   Life expectancy at birth (years)                    29 non-null     object
#  3   Life expectancy at birth (years).1                  29 non-null     object
#  4   Life expectancy at birth (years).2                  29 non-null     object
#  5   Life expectancy at age 60 (years)                   29 non-null     object
#  6   Life expectancy at age 60 (years).1                 29 non-null     object
#  7   Life expectancy at age 60 (years).2                 29 non-null     object
#  8   Healthy life expectancy (HALE) at birth (years)     29 non-null     object
#  9   Healthy life expectancy (HALE) at birth (years).1   29 non-null     object
#  10  Healthy life expectancy (HALE) at birth (years).2   29 non-null     object
#  11  Healthy life expectancy (HALE) at age 60 (years)    29 non-null     object
#  12  Healthy life expectancy (HALE) at age 60 (years).1  29 non-null     object
#  13  Healthy life expectancy (HALE) at age 60 (years).2  29 non-null     object
# dtypes: object(14)
# memory usage: 3.3+ KB

# %%
#remove missing dataset
print('sum of null data in each column')
print(df.isnull().sum())

print('Length before removing missing data', len(df))
df.dropna(inplace=True)

print('Sum of null data in each column after cleaning ')
print(df.isnull().sum())
print("Length after removing missing data", len(df))
# Out:
# sum of null data in each column
# Unnamed: 0                                            0
# Unnamed: 1                                            0
# Life expectancy at birth (years)                      0
# Life expectancy at birth (years).1                    0
# Life expectancy at birth (years).2                    0
# Life expectancy at age 60 (years)                     0
# Life expectancy at age 60 (years).1                   0
# Life expectancy at age 60 (years).2                   0
# Healthy life expectancy (HALE) at birth (years)       0
# Healthy life expectancy (HALE) at birth (years).1     0
# Healthy life expectancy (HALE) at birth (years).2     0
# Healthy life expectancy (HALE) at age 60 (years)      0
# Healthy life expectancy (HALE) at age 60 (years).1    0
# Healthy life expectancy (HALE) at age 60 (years).2    0
# dtype: int64
# Length before removing missing data 29
# Sum of null data in each column after cleaning
# Unnamed: 0                                            0
# Unnamed: 1                                            0
# Life expectancy at birth (years)                      0
# Life expectancy at birth (years).1                    0
# Life expectancy at birth (years).2                    0
# Life expectancy at age 60 (years)                     0
# Life expectancy at age 60 (years).1                   0
# Life expectancy at age 60 (years).2                   0
# Healthy life expectancy (HALE) at birth (years)       0
# Healthy life expectancy (HALE) at birth (years).1     0
# Healthy life expectancy (HALE) at birth (years).2     0
# Healthy life expectancy (HALE) at age 60 (years)      0
# Healthy life expectancy (HALE) at age 60 (years).1    0
# Healthy life expectancy (HALE) at age 60 (years).2    0
# dtype: int64
# Length after removing missing data 29

# %%
#Data exploration after clean dataset
df.describe()
# Out:
#        Unnamed: 0 Unnamed: 1 Life expectancy at birth (years)  \
# count          29         29                               29
# unique          8          5                               29
# top        Global       2019                       Both sexes
# freq            4          7                                1
#
#        Life expectancy at birth (years).1 Life expectancy at birth (years).2  \
# count                                  29                                 29
# unique                                 27                                 27
# top                                  69.8                               69.3
# freq                                    2                                  2
#
#        Life expectancy at age 60 (years) Life expectancy at age 60 (years).1  \
# count                                 29                                  29
# unique                                25                                  28
# top                                 18.8                                17.2
# freq                                   2                                   2
#
#        Life expectancy at age 60 (years).2  \
# count                                   29
# unique                                  27
# top                                   23.6
# freq                                     2
#
#        Healthy life expectancy (HALE) at birth (years)  \
# count                                               29
# unique                                              26
# top                                               58.7
# freq                                                 2
#
#        Healthy life expectancy (HALE) at birth (years).1  \
# count                                                 29
# unique                                                27
# top                                                 60.2
# freq                                                   2
#
#        Healthy life expectancy (HALE) at birth (years).2  \
# count                                                 29
# unique                                                29
# top                                               Female
# freq                                                   1
#
#        Healthy life expectancy (HALE) at age 60 (years)  \
# count                                                29
# unique                                               21
# top                                                13.3
# freq                                                  3
#
#        Healthy life expectancy (HALE) at age 60 (years).1  \
# count                                                  29
# unique                                                 24
# top                                                  15.4
# freq                                                    3
#
#        Healthy life expectancy (HALE) at age 60 (years).2
# count                                                  29
# unique                                                 22
# top                                                  13.6
# freq                                                    4

# %%
df = df.drop(df.index[0])


print(df.corr())
# Out:
# Index(['Unnamed: 1', 'Life expectancy at birth (years)',
#        'Life expectancy at birth (years).1',
#        'Life expectancy at birth (years).2',
#        'Life expectancy at age 60 (years)',
#        'Life expectancy at age 60 (years).1',
#        'Life expectancy at age 60 (years).2',
#        'Healthy life expectancy (HALE) at birth (years)',
#        'Healthy life expectancy (HALE) at birth (years).1',
#        'Healthy life expectancy (HALE) at birth (years).2',
#        'Healthy life expectancy (HALE) at age 60 (years)',
#        'Healthy life expectancy (HALE) at age 60 (years).1',
#        'Healthy life expectancy (HALE) at age 60 (years).2'],
#       dtype='object')
#                                                     Unnamed: 1  \
# Unnamed: 1                                            1.000000
# Life expectancy at birth (years)                      0.388753
# Life expectancy at birth (years).1                    0.424183
# Life expectancy at birth (years).2                    0.354726
# Life expectancy at age 60 (years)                     0.386883
# Life expectancy at age 60 (years).1                   0.465858
# Life expectancy at age 60 (years).2                   0.327046
# Healthy life expectancy (HALE) at birth (years)       0.359832
# Healthy life expectancy (HALE) at birth (years).1     0.392807
# Healthy life expectancy (HALE) at birth (years).2     0.325935
# Healthy life expectancy (HALE) at age 60 (years)      0.330581
# Healthy life expectancy (HALE) at age 60 (years).1    0.417748
# Healthy life expectancy (HALE) at age 60 (years).2    0.268955
#
#                                                     Life expectancy at birth (years)  \
# Unnamed: 1                                                                  0.388753
# Life expectancy at birth (years)                                            1.000000
# Life expectancy at birth (years).1                                          0.995270
# Life expectancy at birth (years).2                                          0.996972
# Life expectancy at age 60 (years)                                           0.941875
# Life expectancy at age 60 (years).1                                         0.932049
# Life expectancy at age 60 (years).2                                         0.928882
# Healthy life expectancy (HALE) at birth (years)                             0.994165
# Healthy life expectancy (HALE) at birth (years).1                           0.993452
# Healthy life expectancy (HALE) at birth (years).2                           0.986360
# Healthy life expectancy (HALE) at age 60 (years)                            0.930855
# Healthy life expectancy (HALE) at age 60 (years).1                          0.953960
# Healthy life expectancy (HALE) at age 60 (years).2                          0.895742
#
#                                                     Life expectancy at birth (years).1  \
# Unnamed: 1                                                                    0.424183
# Life expectancy at birth (years)                                              0.995270
# Life expectancy at birth (years).1                                            1.000000
# Life expectancy at birth (years).2                                            0.984846
# Life expectancy at age 60 (years)                                             0.923298
# Life expectancy at age 60 (years).1                                           0.930457
# Life expectancy at age 60 (years).2                                           0.900605
# Healthy life expectancy (HALE) at birth (years)                               0.984579
# Healthy life expectancy (HALE) at birth (years).1                             0.993193
# Healthy life expectancy (HALE) at birth (years).2                             0.968674
# Healthy life expectancy (HALE) at age 60 (years)                              0.901355
# Healthy life expectancy (HALE) at age 60 (years).1                            0.941269
# Healthy life expectancy (HALE) at age 60 (years).2                            0.856490
#
#                                                     Life expectancy at birth (years).2  \
# Unnamed: 1                                                                    0.354726
# Life expectancy at birth (years)                                              0.996972
# Life expectancy at birth (years).1                                            0.984846
# Life expectancy at birth (years).2                                            1.000000
# Life expectancy at age 60 (years)                                             0.948052
# Life expectancy at age 60 (years).1                                           0.923941
# Life expectancy at age 60 (years).2                                           0.944097
# Healthy life expectancy (HALE) at birth (years)                               0.996038
# Healthy life expectancy (HALE) at birth (years).1                             0.988072
# Healthy life expectancy (HALE) at birth (years).2                             0.994702
# Healthy life expectancy (HALE) at age 60 (years)                              0.946636
# Healthy life expectancy (HALE) at age 60 (years).1                            0.955979
# Healthy life expectancy (HALE) at age 60 (years).2                            0.920154
#
#                                                     Life expectancy at age 60 (years)  \
# Unnamed: 1                                                                   0.386883
# Life expectancy at birth (years)                                             0.941875
# Life expectancy at birth (years).1                                           0.923298
# Life expectancy at birth (years).2                                           0.948052
# Life expectancy at age 60 (years)                                            1.000000
# Life expectancy at age 60 (years).1                                          0.979452
# Life expectancy at age 60 (years).2                                          0.988181
# Healthy life expectancy (HALE) at birth (years)                              0.927847
# Healthy life expectancy (HALE) at birth (years).1                            0.910544
# Healthy life expectancy (HALE) at birth (years).2                            0.933590
# Healthy life expectancy (HALE) at age 60 (years)                             0.986324
# Healthy life expectancy (HALE) at age 60 (years).1                           0.991380
# Healthy life expectancy (HALE) at age 60 (years).2                           0.960515
#
#                                                     Life expectancy at age 60 (years).1  \
# Unnamed: 1                                                                     0.465858
# Life expectancy at birth (years)                                               0.932049
# Life expectancy at birth (years).1                                             0.930457
# Life expectancy at birth (years).2                                             0.923941
# Life expectancy at age 60 (years)                                              0.979452
# Life expectancy at age 60 (years).1                                            1.000000
# Life expectancy at age 60 (years).2                                            0.938981
# Healthy life expectancy (HALE) at birth (years)                                0.901055
# Healthy life expectancy (HALE) at birth (years).1                              0.900027
# Healthy life expectancy (HALE) at birth (years).2                              0.892141
# Healthy life expectancy (HALE) at age 60 (years)                               0.937354
# Healthy life expectancy (HALE) at age 60 (years).1                             0.978884
# Healthy life expectancy (HALE) at age 60 (years).2                             0.886984
#
#                                                     Life expectancy at age 60 (years).2  \
# Unnamed: 1                                                                     0.327046
# Life expectancy at birth (years)                                               0.928882
# Life expectancy at birth (years).1                                             0.900605
# Life expectancy at birth (years).2                                             0.944097
# Life expectancy at age 60 (years)                                              0.988181
# Life expectancy at age 60 (years).1                                            0.938981
# Life expectancy at age 60 (years).2                                            1.000000
# Healthy life expectancy (HALE) at birth (years)                                0.929729
# Healthy life expectancy (HALE) at birth (years).1                              0.903259
# Healthy life expectancy (HALE) at birth (years).2                              0.944276
# Healthy life expectancy (HALE) at age 60 (years)                               0.995687
# Healthy life expectancy (HALE) at age 60 (years).1                             0.976856
# Healthy life expectancy (HALE) at age 60 (years).2                             0.988550
#
#                                                     Healthy life expectancy (HALE) at birth (years)  \
# Unnamed: 1                                                                                 0.359832
# Life expectancy at birth (years)                                                           0.994165
# Life expectancy at birth (years).1                                                         0.984579
# Life expectancy at birth (years).2                                                         0.996038
# Life expectancy at age 60 (years)                                                          0.927847
# Life expectancy at age 60 (years).1                                                        0.901055
# Life expectancy at age 60 (years).2                                                        0.929729
# Healthy life expectancy (HALE) at birth (years)                                            1.000000
# Healthy life expectancy (HALE) at birth (years).1                                          0.995278
# Healthy life expectancy (HALE) at birth (years).2                                          0.996403
# Healthy life expectancy (HALE) at age 60 (years)                                           0.933113
# Healthy life expectancy (HALE) at age 60 (years).1                                         0.943975
# Healthy life expectancy (HALE) at age 60 (years).2                                         0.908848
#
#                                                     Healthy life expectancy (HALE) at birth (years).1  \
# Unnamed: 1                                                                                   0.392807
# Life expectancy at birth (years)                                                             0.993452
# Life expectancy at birth (years).1                                                           0.993193
# Life expectancy at birth (years).2                                                           0.988072
# Life expectancy at age 60 (years)                                                            0.910544
# Life expectancy at age 60 (years).1                                                          0.900027
# Life expectancy at age 60 (years).2                                                          0.903259
# Healthy life expectancy (HALE) at birth (years)                                              0.995278
# Healthy life expectancy (HALE) at birth (years).1                                            1.000000
# Healthy life expectancy (HALE) at birth (years).2                                            0.983571
# Healthy life expectancy (HALE) at age 60 (years)                                             0.906324
# Healthy life expectancy (HALE) at age 60 (years).1                                           0.933880
# Healthy life expectancy (HALE) at age 60 (years).2                                           0.872469
#
#                                                     Healthy life expectancy (HALE) at birth (years).2  \
# Unnamed: 1                                                                                   0.325935
# Life expectancy at birth (years)                                                             0.986360
# Life expectancy at birth (years).1                                                           0.968674
# Life expectancy at birth (years).2                                                           0.994702
# Life expectancy at age 60 (years)                                                            0.933590
# Life expectancy at age 60 (years).1                                                          0.892141
# Life expectancy at age 60 (years).2                                                          0.944276
# Healthy life expectancy (HALE) at birth (years)                                              0.996403
# Healthy life expectancy (HALE) at birth (years).1                                            0.983571
# Healthy life expectancy (HALE) at birth (years).2                                            1.000000
# Healthy life expectancy (HALE) at age 60 (years)                                             0.948066
# Healthy life expectancy (HALE) at age 60 (years).1                                           0.944042
# Healthy life expectancy (HALE) at age 60 (years).2                                           0.932830
#
#                                                     Healthy life expectancy (HALE) at age 60 (years)  \
# Unnamed: 1                                                                                  0.330581
# Life expectancy at birth (years)                                                            0.930855
# Life expectancy at birth (years).1                                                          0.901355
# Life expectancy at birth (years).2                                                          0.946636
# Life expectancy at age 60 (years)                                                           0.986324
# Life expectancy at age 60 (years).1                                                         0.937354
# Life expectancy at age 60 (years).2                                                         0.995687
# Healthy life expectancy (HALE) at birth (years)                                             0.933113
# Healthy life expectancy (HALE) at birth (years).1                                           0.906324
# Healthy life expectancy (HALE) at birth (years).2                                           0.948066
# Healthy life expectancy (HALE) at age 60 (years)                                            1.000000
# Healthy life expectancy (HALE) at age 60 (years).1                                          0.981908
# Healthy life expectancy (HALE) at age 60 (years).2                                          0.991570
#
#                                                     Healthy life expectancy (HALE) at age 60 (years).1  \
# Unnamed: 1                                                                                   0.417748
# Life expectancy at birth (years)                                                             0.953960
# Life expectancy at birth (years).1                                                           0.941269
# Life expectancy at birth (years).2                                                           0.955979
# Life expectancy at age 60 (years)                                                            0.991380
# Life expectancy at age 60 (years).1                                                          0.978884
# Life expectancy at age 60 (years).2                                                          0.976856
# Healthy life expectancy (HALE) at birth (years)                                              0.943975
# Healthy life expectancy (HALE) at birth (years).1                                            0.933880
# Healthy life expectancy (HALE) at birth (years).2                                            0.944042
# Healthy life expectancy (HALE) at age 60 (years)                                             0.981908
# Healthy life expectancy (HALE) at age 60 (years).1                                           1.000000
# Healthy life expectancy (HALE) at age 60 (years).2                                           0.950603
#
#                                                     Healthy life expectancy (HALE) at age 60 (years).2
# Unnamed: 1                                                                                   0.268955
# Life expectancy at birth (years)                                                             0.895742
# Life expectancy at birth (years).1                                                           0.856490
# Life expectancy at birth (years).2                                                           0.920154
# Life expectancy at age 60 (years)                                                            0.960515
# Life expectancy at age 60 (years).1                                                          0.886984
# Life expectancy at age 60 (years).2                                                          0.988550
# Healthy life expectancy (HALE) at birth (years)                                              0.908848
# Healthy life expectancy (HALE) at birth (years).1                                            0.872469
# Healthy life expectancy (HALE) at birth (years).2                                            0.932830
# Healthy life expectancy (HALE) at age 60 (years)                                             0.991570
# Healthy life expectancy (HALE) at age 60 (years).1                                           0.950603
# Healthy life expectancy (HALE) at age 60 (years).2                                           1.000000

# %%
#Split the data set

train, test = train_test_split(df, test_size = 0.2, random_state = 142)
print('Train set shape', train.shape)
print('Test set shape', test.shape)
# Out:
# Train set shape (20, 13)
# Test set shape (6, 13)

# %%
X_train = train[['Life expectancy at birth (years).1', 'Life expectancy at age 60 (years)', 'Life expectancy at age 60 (years).2']]
y_train = train[['Unnamed: 1']]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#4 Logistic Regression

lr = LogisticRegression().fit(X_train, y_train)

y_pred_train = lr.predict(X_train)
y_pred_test = lr.predict(X_test)


# train_accuracy = accuracy_score(Y_train, train_predictions)

# %%
#Calculation accuracy on training set

print('Accursacy of traing set', accuracy_score(y_train, y_pred_train))
# Out:
# Accursacy of traing set 0.4

# %%
#KNN

# %%
from sklearn.datasets import make_classification
from sklearn.neighbors import KNeighborsClassifier
# from sklearn.metrices import accuracy_score

# %%
#create KNN classifier model

clf = KNeighborsClassifier(n_neighbors = 7)
clf.fit(X_train , y_train)

clf.fit(X_test , y_test)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
#Using model to predict training

y_pred = clf.predict(X_train)
accuracy = accuracy_score(y_pred, y_train)
print('Training dataset accuracy is:', accuracy)
# Out:
# Training dataset accuracy is: 0.6

# %%
#Using model to predict train
y_pred = clf.predict(X_train)
accuracy = accuracy_score(y_pred, y_train)
print('Train dataset accuracy is:', accuracy)
# Out:
# Test dataset accuracy is: 0.0
# Train dataset accuracy is: 0.6

# %%
#Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

#define search space for parameer grid
parameter_grid = {'n_neighbors': range(3,30)}

# %%
#create learning model

knn_clf = KNeighborsClassifier()
clf = GridSearchCV (knn_clf, parameter_grid, scoring='accuracy', cv = 5)
clf.fit(X_train , y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(3, 30)}, scoring='accuracy')

# %%
cv_results = clf.cv_results_
mean_test_accuracy = cv_results['mean_test_score']
knn_params = cv_results['params']

# %%
k_values = [param_dict['n_neighbors'] for param_dict in knn_params]

plt.figure(figsize=(9, 7))
plt.plot(k_values, mean_test_accuracy)

# %%
# identify bes parameter

print('Best K value', clf.best_params_['n_neighbors'])
print('Accuracy' , clf.best_score_)
# Out:
# Best K value 3
# Accuracy 0.45

# %%
The graph shows how the mean test scores vary with K values
and it might show a trend where the accuracy initially increases with K, 
then stabilizes or decreases after reaching an optimal value.
# Out:
#   Cell In[85], line 1
#     The graph shows how the mean test scores vary with K values
#         ^
# SyntaxError: invalid syntax
